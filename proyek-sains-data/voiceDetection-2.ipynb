# %%
import os
import pandas as pd
import tsfel
import librosa

# %%
base_path = "data/voice"

cfg = tsfel.get_features_by_domain()

all_features = []

for person in os.listdir(base_path):
    person_path = os.path.join(base_path, person)
    if not os.path.isdir(person_path):
        continue

    for action in os.listdir(person_path):
        action_path = os.path.join(person_path, action)
        if not os.path.isdir(action_path):
            continue

        for filename in os.listdir(action_path):
            if filename.endswith(".mp3") or filename.endswith(".wav"):
                file_path = os.path.join(action_path, filename)

                try:
                    signal, sr = librosa.load(file_path, sr=None)
                    features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)

                    features['label_orang'] = person
                    features['label_aksi'] = action
                    features['file'] = filename

                    all_features.append(features)

                    print(f"✅ Selesai ekstraksi: {file_path}")
                except Exception as e:
                    print(f"❌ Gagal memproses {file_path}: {e}")

final_df = pd.concat(all_features, ignore_index=True)

final_df.to_csv("data/features_tsfel_all_with_person_label.csv", index=False)
print("✅ Semua fitur berhasil disimpan ke 'data/features_tsfel_all_with_person_label.csv'")
# Out:
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka1.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka10.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka100.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka11.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka12.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka13.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka14.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka15.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka16.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka17.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka18.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka19.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka2.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka20.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka21.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka22.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka23.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka24.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka25.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka26.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka27.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka28.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka29.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka3.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka30.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka31.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka32.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka33.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka34.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka35.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka36.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka37.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka38.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka39.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka4.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka40.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka41.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka42.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka43.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka44.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka45.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka46.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka47.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka48.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka49.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka5.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka50.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka51.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka52.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka53.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka54.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka55.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka56.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka57.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka58.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka59.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka6.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka60.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka61.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka62.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka63.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka64.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka65.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka66.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka67.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka68.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka69.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka7.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka70.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka71.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka72.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka73.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka74.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka75.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka76.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka77.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka78.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka79.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka8.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka80.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka81.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka82.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka83.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka84.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka85.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka86.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka87.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka88.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka89.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka9.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka90.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka91.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka92.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka93.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka94.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka95.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka96.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka97.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka98.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\buka\buka99.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup1.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup10.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup100.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup11.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup12.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup13.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup14.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup15.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup16.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup17.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup18.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup19.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup2.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup20.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup21.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup22.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup23.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup24.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup25.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup26.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup27.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup28.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup29.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup3.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup30.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup31.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup32.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup33.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup34.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup35.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup36.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup37.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup38.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup39.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup4.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup40.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup41.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup42.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup43.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup44.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup45.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup46.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup47.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup48.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup49.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup5.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup50.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup51.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup52.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup53.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup54.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup55.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup56.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup57.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup58.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup59.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup6.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup60.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup61.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup62.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup63.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup64.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup65.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup66.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup67.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup68.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup69.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup7.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup70.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup71.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup72.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup73.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup74.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup75.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup76.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup77.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup78.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\imam\tutup\tutup79.wav
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
# ...
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (53).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (54).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (55).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (56).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (57).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (58).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (59).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (6).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (60).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (61).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (62).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (63).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (64).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (65).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (66).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (67).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (68).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (69).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (7).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (70).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (71).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (72).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (73).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (74).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (75).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (76).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (77).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (78).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (79).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (8).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (80).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (81).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (82).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (83).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (84).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (85).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (86).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (87).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (88).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (89).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (9).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (90).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (91).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (92).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (93).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (94).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (95).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (96).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (97).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (98).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) (99).mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com) - 2025-10-27T103801.482.mp3
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\2464330767.py:23: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, signal, verbose=0)
# ✅ Selesai ekstraksi: data/voice\mufid\tutup\Record (online-voice-recorder.com).mp3
# ✅ Semua fitur berhasil disimpan ke 'data/features_tsfel_all_with_person_label.csv'

# %%
data = "data/features_tsfel_all_with_person_label.csv"

df = pd.read_csv(data)

print("✅ Data berhasil dibaca!")
print("Jumlah sample:", len(df))
print("Jumlah kolom :", int(len(df.columns)) - 3)
# Out:
# ✅ Data berhasil dibaca!
# Jumlah sample: 603
# Jumlah kolom : 156

# %%
df.head()
# Out:
#    0_Absolute energy  0_Area under the curve  0_Autocorrelation  \
# 0          17.701422                6.699155               13.0
# 1        4076.943443              144.812594                1.0
# 2           7.288779                4.434814               13.0
# 3          20.110433                7.614396               14.0
# 4        3118.204500              142.493144                3.0
#
#    0_Average power  0_Centroid  0_ECDF Percentile Count_0  \
# 0         0.010597  690.916973                    33408.0
# 1         2.803468  697.658083                    29085.0
# 2         0.004713  640.792712                    30933.0
# 3         0.010595  785.095241                    37963.0
# 4         1.679877  873.811973                    37124.0
#
#    0_ECDF Percentile Count_1  0_ECDF Percentile_0  0_ECDF Percentile_1  \
# 0                   133632.0            -0.000732             0.000824
# 1                   116340.0            -0.133514             0.134033
# 2                   123733.0            -0.000580             0.000519
# 3                   151854.0            -0.000732             0.000824
# 4                   148497.0            -0.096771             0.096527
#
#    0_ECDF_0  ...  0_Wavelet variance_3.12Hz  0_Wavelet variance_3.57Hz  \
# 0  0.000006  ...                   0.000803                   0.000537
# 1  0.000007  ...                   0.077163                   0.058743
# 2  0.000006  ...                   0.000361                   0.000241
# 3  0.000005  ...                   0.000620                   0.000398
# 4  0.000005  ...                   0.086602                   0.067813
#
#    0_Wavelet variance_4.17Hz  0_Wavelet variance_5.0Hz  \
# 0                   0.000320                  0.000170
# 1                   0.043568                  0.032809
# 2                   0.000143                  0.000076
# 3                   0.000233                  0.000125
# 4                   0.048252                  0.031444
#
#    0_Wavelet variance_6.25Hz  0_Wavelet variance_8.33Hz  0_Zero crossing rate  \
# 0                   0.000082                   0.000034               16559.0
# 1                   0.026371                   0.022927               66499.0
# 2                   0.000036                   0.000015               14974.0
# 3                   0.000063                   0.000026               16559.0
# 4                   0.019939                   0.013732               82152.0
#
#    label_orang  label_aksi         file
# 0         imam        buka    buka1.wav
# 1         imam        buka   buka10.wav
# 2         imam        buka  buka100.wav
# 3         imam        buka   buka11.wav
# 4         imam        buka   buka12.wav
#
# [5 rows x 159 columns]

# %%
missing = df.isnull().sum()
print(missing[missing > 0])
# Out:
# Series([], dtype: int64)

# %%
X = df.drop(columns=["label_aksi", "label_orang", "file"])
y_action = df["label_aksi"]
y_person = df["label_orang"]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder_action = LabelEncoder()
label_encoder_person = LabelEncoder()

y_action_encoded = label_encoder_action.fit_transform(y_action)
y_person_encoded = label_encoder_person.fit_transform(y_person)

print(label_encoder_action.classes_)
print(label_encoder_person.classes_)
# Out:
# ['buka' 'tutup']
# ['imam' 'maulana' 'mufid']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train_a, X_test_a, y_train_a, y_test_a = train_test_split(
    X_scaled, y_action_encoded, test_size=0.2, random_state=42, stratify=y_action_encoded
)

X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(
    X_scaled, y_person_encoded, test_size=0.2, stratify=y_person_encoded
)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# #### Menggunakan semua fitur

# %%
model_action = RandomForestClassifier(n_estimators=200, random_state=42)
model_action.fit(X_train_a, y_train_a)
y_pred_action = model_action.predict(X_test_a)

print("\n===== Model: LABEL_AKSI =====")
print(f"Akurasi: {accuracy_score(y_test_a, y_pred_action):.4f}")
print(confusion_matrix(y_test_a, y_pred_action))
print(classification_report(y_test_a, y_pred_action, target_names=label_encoder_action.classes_))
# Out:
# ===== Model: LABEL_AKSI =====
# Akurasi: 0.9339
# [[57  3]
#  [ 5 56]]
#               precision    recall  f1-score   support
#
#         buka       0.92      0.95      0.93        60
#        tutup       0.95      0.92      0.93        61
#
#     accuracy                           0.93       121
#    macro avg       0.93      0.93      0.93       121
# weighted avg       0.93      0.93      0.93       121

# %%
model_person = RandomForestClassifier(n_estimators=200, random_state=42)
model_person.fit(X_train_b, y_train_b)
y_pred_action = model_person.predict(X_test_b)

print("\n===== Model: LABEL_ORANG =====")
print(f"Akurasi: {accuracy_score(y_test_b, y_pred_action):.4f}")
print(confusion_matrix(y_test_b, y_pred_action))
print(classification_report(y_test_b, y_pred_action, target_names=label_encoder_person.classes_))
# Out:
# ===== Model: LABEL_ORANG =====
# Akurasi: 1.0000
# [[40  0  0]
#  [ 0 40  0]
#  [ 0  0 41]]
#               precision    recall  f1-score   support
#
#         imam       1.00      1.00      1.00        40
#      maulana       1.00      1.00      1.00        40
#        mufid       1.00      1.00      1.00        41
#
#     accuracy                           1.00       121
#    macro avg       1.00      1.00      1.00       121
# weighted avg       1.00      1.00      1.00       121

# %% [markdown]
# #### Rank fitur menggunakan information gain

# %%
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt
import seaborn as sns

mutual_information_action = mutual_info_classif(X, y_action_encoded, random_state=42)
mutual_information_person = mutual_info_classif(X, y_person_encoded, random_state=42)

# %%
mutual_information_df_action = pd.DataFrame({
    "Feature": X.columns,
    "MI_Score": mutual_information_action
}).sort_values(by="MI_Score", ascending=False)

print("🔥 Top 10 Fitur Paling Informatif untuk LABEL_AKSI (buka/tutup):")
print(mutual_information_df_action.head(10), "\n")
# Out:
# 🔥 Top 10 Fitur Paling Informatif untuk LABEL_AKSI (buka/tutup):
#                                  Feature  MI_Score
# 74                    0_Spectral entropy  0.341894
# 2                      0_Autocorrelation  0.321188
# 60                    0_Median frequency  0.292388
# 66                     0_Power bandwidth  0.251206
# 130              0_Wavelet energy_3.12Hz  0.243266
# 140  0_Wavelet standard deviation_3.12Hz  0.243266
# 149            0_Wavelet variance_3.12Hz  0.241802
# 19                             0_Entropy  0.226030
# 68                     0_Signal distance  0.218839
# 54                  0_Mean absolute diff  0.218836

# %%
mutual_information_df_person = pd.DataFrame({
    "Feature": X.columns,
    "MI_Score": mutual_information_person
}).sort_values(by="MI_Score", ascending=False)

print("🔥 Top 10 Fitur Paling Informatif untuk LABEL_ORANG (imam/mufid):")
print(mutual_information_df_person.head(10), "\n")
# Out:
# 🔥 Top 10 Fitur Paling Informatif untuk LABEL_ORANG (imam/mufid):
#                                     Feature  MI_Score
# 19                                0_Entropy  1.073083
# 68                        0_Signal distance  0.872838
# 87   0_Spectrogram mean coefficient_14.52Hz  0.822783
# 76       0_Spectral positive turning points  0.802786
# 85   0_Spectrogram mean coefficient_11.29Hz  0.800590
# 114   0_Spectrogram mean coefficient_9.68Hz  0.798386
# 88   0_Spectrogram mean coefficient_16.13Hz  0.769194
# 103  0_Spectrogram mean coefficient_38.71Hz  0.754070
# 86    0_Spectrogram mean coefficient_12.9Hz  0.732056
# 14                                 0_ECDF_5  0.731288

# %%
top_n = 20
top_aksi = mutual_information_df_action.sort_values(by="MI_Score", ascending=False).head(top_n)
top_orang = mutual_information_df_person.sort_values(by="MI_Score", ascending=False).head(top_n)

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

sns.barplot(
    data=top_aksi,
    y="Feature",
    x="MI_Score",
    palette="Blues_r",
    ax=axes[0]
)
axes[0].set_title(f"📊 Top {top_n} Fitur berdasarkan Information Gain - LABEL_AKSI", fontsize=13)
axes[0].set_xlabel("Mutual Information Score", fontsize=11)
axes[0].set_ylabel("")
axes[0].tick_params(axis='y', labelsize=9)

sns.barplot(
    data=top_orang,
    y="Feature",
    x="MI_Score",
    palette="Reds_r",
    ax=axes[1]
)
axes[1].set_title(f"📊 Top {top_n} Fitur berdasarkan Information Gain - LABEL_ORANG", fontsize=13)
axes[1].set_xlabel("Mutual Information Score", fontsize=11)
axes[1].set_ylabel("")
axes[1].tick_params(axis='y', labelsize=9)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\1192745994.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\1192745994.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\risqi\AppData\Local\Temp\ipykernel_34580\1192745994.py:31: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# c:\Users\risqi\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### Feature selection

# %%
threshold = 0.2

selected_features_action = mutual_information_df_action[mutual_information_df_action['MI_Score'] > threshold]['Feature'].tolist()
selected_features_person = mutual_information_df_person[mutual_information_df_person['MI_Score'] > threshold]['Feature'].tolist()

selected_features_action = list(selected_features_action)
selected_features_person = list(selected_features_person)

X_selected_action = X[selected_features_action]
X_selected_person = X[selected_features_person]

print(f"Jumlah fitur untuk label aksi: {len(selected_features_action)}")
print(f"Jumlah fitur untuk label orang: {len(selected_features_person)}")
# Out:
# Jumlah fitur untuk label aksi: 23
# Jumlah fitur untuk label orang: 131

# %% [markdown]
# #### Modeling again, after feature selection

# %%
X_train_a, X_test_a, y_train_a, y_test_a = train_test_split(
    X_selected_action, y_action, test_size=0.2, random_state=42, stratify=y_action
)

X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(
    X_selected_person, y_person, test_size=0.2, random_state=42, stratify=y_person
)

# %%
scaler_action = StandardScaler()
scaler_person = StandardScaler()

X_train_a_scaled = scaler_action.fit_transform(X_train_a)
X_test_a_scaled = scaler_action.transform(X_test_a)

X_train_b_scaled = scaler_person.fit_transform(X_train_b)
X_test_b_scaled = scaler_person.transform(X_test_b)

# %%
model_action = RandomForestClassifier(n_estimators=200, random_state=42)
model_action.fit(X_train_a_scaled, y_train_a)

y_pred_action = model_action.predict(X_test_a_scaled)

print("=== Evaluasi Model untuk LABEL_AKSI ===")
print(classification_report(y_test_a, y_pred_action))
print("Akurasi:", accuracy_score(y_test_a, y_pred_action))

plt.figure(figsize=(5,4))
sns.heatmap(confusion_matrix(y_test_a, y_pred_action), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix - LABEL_AKSI")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# === Evaluasi Model untuk LABEL_AKSI ===
#               precision    recall  f1-score   support
#
#         buka       0.93      0.93      0.93        60
#        tutup       0.93      0.93      0.93        61
#
#     accuracy                           0.93       121
#    macro avg       0.93      0.93      0.93       121
# weighted avg       0.93      0.93      0.93       121
#
# Akurasi: 0.9338842975206612

# %%
model_person = RandomForestClassifier(n_estimators=200, random_state=42)
model_person.fit(X_train_b_scaled, y_train_b)

y_pred_person = model_person.predict(X_test_b_scaled)

print("\n=== Evaluasi Model untuk LABEL_ORANG ===")
print(classification_report(y_test_b, y_pred_person))
print("Akurasi:", accuracy_score(y_test_b, y_pred_person))

plt.figure(figsize=(5,4))
sns.heatmap(confusion_matrix(y_test_b, y_pred_person), annot=True, fmt='d', cmap='OrRd')
plt.title("Confusion Matrix - LABEL_ORANG")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# === Evaluasi Model untuk LABEL_ORANG ===
#               precision    recall  f1-score   support
#
#         imam       1.00      1.00      1.00        40
#      maulana       1.00      1.00      1.00        40
#        mufid       1.00      1.00      1.00        41
#
#     accuracy                           1.00       121
#    macro avg       1.00      1.00      1.00       121
# weighted avg       1.00      1.00      1.00       121
#
# Akurasi: 1.0

# %% [markdown]
# #### Simpan model & Scaler

# %%
import pickle

with open('model/model_action.pkl', 'wb') as f:
    pickle.dump(model_action, f)

with open('model/model_person.pkl', 'wb') as f:
    pickle.dump(model_person, f)

with open('model/scaler_action.pkl', 'wb') as f:
    pickle.dump(scaler_action, f)

with open('model/scaler_person.pkl', 'wb') as f:
    pickle.dump(scaler_person, f)

print("✅ Kedua model & scaler berhasil disimpan sebagai file .pkl")
# Out:
# ✅ Kedua model & scaler berhasil disimpan sebagai file .pkl

# %%
import json

with open('model/features_action.json', 'w') as f:
    json.dump(selected_features_action, f)

with open('model/features_person.json', 'w') as f:
    json.dump(selected_features_person, f)

# %%
import os

for f in ["model_action.pkl", "model_person.pkl", "scaler_action.pkl", "scaler_person.pkl", "features_action.json", "features_person.json"]:
    path = os.path.join("model", f)
    if os.path.exists(path):
        os.remove(path)
        print(f"🗑️ Deleted old {f}")
# Out:
# 🗑️ Deleted old model_action.pkl
# 🗑️ Deleted old model_person.pkl
# 🗑️ Deleted old scaler_action.pkl
# 🗑️ Deleted old scaler_person.pkl
# 🗑️ Deleted old features_action.json
# 🗑️ Deleted old features_person.json
